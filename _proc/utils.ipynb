# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(load_model)
# Out:
# ---
#
# ### load_model
#
# >      load_model (model_name, model_version, iter)

# %%
#| echo: false
#| output: asis
show_doc(save_model)
# Out:
# ---
#
# ### save_model
#
# >      save_model (model, model_name, model_version, iter)
